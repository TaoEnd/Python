# %%
# coding:utf-8
import numpy as np
from matplotlib import pyplot as plt

# %%
# 玫瑰图花瓣的数量
n = 8
angle = np.arange(0, 2*np.pi, np.pi/n)
radius = np.random.randint(3, 15, 16)
print(radius)
# axes表示整个画布, 0, 0, 1, 1分别表示左上角和右下角坐标
plt.axes([0, 0, 1, 1], polar=True)
color = np.random.random(size=24).reshape((8, 3))
plt.bar(angle, radius, color=color)
plt.show()
# Out:
# [ 6 10 11  7  5  6  7 10 10  6 13 12  7  4  7 12]
